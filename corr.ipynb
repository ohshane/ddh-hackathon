# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from collections import Counter
from pathlib import Path
from sympy import symbols, solve

__file__ = Path(os.path.abspath('__file__'))
root_path = __file__.parent
data_path = root_path / 'data'

sets = ['all']

print(f'{__file__  = }')

dfs = {}
for s in sets:
    dfs[s] = pd.read_csv(root_path / 'new' / f'{s}.csv')
# Out:
# __file__  = PosixPath('/home/shane/workspace/hackathon-ddh/__file__')

# %%
pd.plotting.scatter_matrix(dfs['all'], figsize=(20,20))
plt.figure(figsize=(20,20))

# %%
df = pd.read_csv('ddh.csv')
cols = [
    'diagnose',
    'b_angle',
    'b_diagnose',
    'a_diagnose',
    'alpha_angle',
    'alpha_y',
    'alpha_x',
    'sex',
    'age',
    'alpha_ratio',
    'a_angle',
    'containment']

pd.plotting.scatter_matrix(df[cols], figsize=(20,20))
plt.figure(figsize=(20,20))
